# %%
import os
import sys
import joblib
import FE_0823 as FE
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
import imp
imp.reload(FE)
# Out:
# <module 'FE_0823' from '/Users/jinseok/Jupyter/bigcon/Shopping_GG/2. FE/FE_0823.py'>

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
sale = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'sale_data_v05_0828.xlsx'))
meta = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'sale_meta_v04_0823.xlsx'))
item = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'item_meta_v04_0828.xlsx'))

# %% [markdown]
# # 1. FE

# %%
sale = sale.merge(item[['NEW상품명', 'NEW_최고판매단가']], on = 'NEW상품명', how = 'left')

# %%
sale['판매량01'] = sale['취급액'] / sale['판매단가']

# %%
sale['판매량02'] = sale['취급액'] / sale['NEW_최고판매단가']

# %%
temp.columns = ['NEW상품명', '판매량01', '판매량02']

# %%
import math

# %%
sale['판매량01'] = sale['판매량01'].fillna(0).apply(lambda x : math.ceil(x))

# %%
temp = sale.groupby('NEW상품명').agg({
    '판매량01' : [('판매량01', np.mean)],
    '판매량02' : [('판매량02', np.mean)]
}).reset_index()

# %%
temp.columns = ['NEW상품명', '평균판매량01', '평균판매량02']

# %%
# 같은 상품으로 설정한 경우에도 가격에 대한 주문량이 크게 차이나는 경우가 있음
abs(temp['판매량01'] - temp['판매량02']).sort_values()
# Out:
# 549      0.016
# 1242     0.017
# 79       0.021
# 848      0.022
# 74       0.022
#          ...
# 527    224.453
# 101    230.347
# 95     242.107
# 1064   301.909
# 598    554.511
# Length: 1364, dtype: float64

# %%
sale['방송월'] = sale['방송일시'].dt.month

# %%
sale['방송시간'] = sale['방송일시'].dt.hour

# %%
sale['방송시간(분))'] = sale['방송일시'].dt.minute

# %% [markdown]
# ## 01. 판매량과 상품군별/방송월별/방송시간별/방송분별

# %%
pd.pivot_table(sale, index = 'NEW상품명', columns = '방송시간', values = '판매량01', aggfunc = np.sum).head(50)
# Out:
# 방송시간                                     0        1       2        6   \
# NEW상품명
# 100% 리얼 착즙 석류 4박스                       nan      nan     nan      nan
# 3D매쉬 냉수마찰 물매트                       431.000      nan     nan      nan
# AAA 남성 트레킹화 3종                          nan      nan     nan      nan
# AAA 여성 트레킹화 3종                          nan      nan     nan      nan
# AAB의 든든한 콩국수                            nan      nan     nan      nan
# AAB의 소곱창 전골 800g 8팩                     nan      nan     nan      nan
# AAC 한우소머니 양곰탕                           nan      nan     nan      nan
# AAC 한우소머리 곰탕                            nan      nan     nan      nan
# AAC 한우소머리 곰탕 양곰탕세트                      nan      nan     nan      nan
# AAD 남성 소가죽 구름 샌들                        nan  416.000     nan  403.000
# AAD 도트펀칭 컴포트 슬립온                        nan      nan     nan      nan
# AAD 소가죽 올데이슬립온                          nan  471.000 112.000      nan
# AAD 소가죽 투웨이 샌들                          nan      nan     nan 1606.000
# AAD 여성 소가죽 구름 샌들                        nan 1222.000     nan 1447.000
# AAE LA 갈비 7팩                            nan      nan     nan      nan
# AHC 스킨케어링 톤커버크림                         nan      nan     nan      nan
# BBC&IZUMI 여성 레이스런닝 브라 패키지           310.000  201.000     nan      nan
# CERINI by PAT 남성 기모 릴렉스팬츠               nan  297.000 235.000      nan
# CERINI by PAT 남성 기모집업니트 3종              nan  339.000 176.000      nan
# CERINI by PAT 남성 니트 스웨터 4종              nan      nan     nan      nan
# CERINI by PAT 남성 소프트 기모 릴렉스 팬츠          nan      nan     nan      nan
# CERINI by PAT 남성 스프링 릴렉스 팬츠 3종     1259.000      nan     nan      nan
# CERINI by PAT 남성 썸머 쿨 카라 티셔츠 5종         nan      nan     nan 2375.000
# CERINI by PAT 남성 어반 릴렉스 팬츠 3종       632.000  540.000     nan      nan
# CERINI by PAT 남성 어반 카라 티셔츠 4종           nan  476.000     nan 4411.000
# CERINI by PAT 남성 에어 카라티셔츠 4종            nan 1311.000     nan      nan
# CERINI by PAT 남성 에어 카타티셔츠 4종            nan      nan     nan      nan
# CERINI by PAT 남성 여름 에어윈디 릴렉스 팬츠 3종 1591.000  743.000     nan      nan
# CERINI by PAT 남성 집업니트 4종                nan      nan     nan      nan
# CERINI by PAT 남성 캐주얼 셔츠 4종          933.000      nan     nan      nan
# CERINI by PAT 남성 풀패키지 기모니트 3종           nan      nan     nan      nan
# DIOR 선글라스(SIDERAL)                 1348.000  170.000     nan      nan
# EXR 남성 리버시블 자켓                          nan      nan     nan      nan
# EXR 남성 멀티패키지 세트 3종                  212.000      nan     nan      nan
# EXR 남성 워터 액티비티 5종                       nan      nan     nan      nan
# EXR 남성 퍼포먼스 패딩 점퍼                       nan      nan     nan      nan
# EXR 여성 리버시블 자켓                          nan      nan     nan      nan
# EXR 여성 멀티패키지 세트 3종                  327.000      nan     nan      nan
# EXR 여성 워터 액티비티 5종                       nan      nan     nan      nan
# EXR 여성 퍼포먼스 패딩 점퍼                       nan      nan     nan      nan
# IH 옛 가마솥 세트                             nan      nan     nan 3814.000
# K-SWISS 남성 PK티셔츠 4종                     nan      nan     nan      nan
# K-SWISS 남성 기모티셔츠 5종                 748.000      nan     nan      nan
# K-SWISS 남성 벤치코트                         nan  293.000     nan      nan
# K-SWISS 남성 아웃도어 팬츠 3종               162.000      nan     nan      nan
# K-SWISS 남성 약기모 팬츠 3종                    nan      nan     nan      nan
# K-SWISS 남성 약기모팬츠 3종                1210.000 1051.000     nan      nan
# K-SWISS 남성 에어핏 트랙수트                     nan      nan     nan      nan
# K-SWISS 남성 에어핏트랙수트                 2049.000  319.000     nan      nan
# K-SWISS 남성 웜테크 벤치코트                     nan      nan     nan      nan
#
# 방송시간                                     7         8        9        10  \
# NEW상품명
# 100% 리얼 착즙 석류 4박스                       nan  1194.000      nan      nan
# 3D매쉬 냉수마찰 물매트                           nan       nan      nan      nan
# AAA 남성 트레킹화 3종                          nan   838.000  739.000  867.000
# AAA 여성 트레킹화 3종                          nan   558.000  516.000  484.000
# AAB의 든든한 콩국수                            nan       nan      nan      nan
# AAB의 소곱창 전골 800g 8팩                     nan       nan      nan 1921.000
# AAC 한우소머니 양곰탕                           nan       nan      nan      nan
# AAC 한우소머리 곰탕                            nan       nan      nan      nan
# K-SWISS 남성 웜테크 벤치코트                     nan       nan      nan      nan
#
# 방송시간                                      11       12  ...       14       15  \
# NEW상품명                                                 ...
# 100% 리얼 착즙 석류 4박스                        nan      nan  ... 2366.000      nan
# 3D매쉬 냉수마찰 물매트                            nan      nan  ...      nan      nan
# AAA 남성 트레킹화 3종                       687.000      nan  ...  635.000  928.000
# AAA 여성 트레킹화 3종                       430.000      nan  ...  406.000  534.000
# AAB의 든든한 콩국수                             nan      nan  ...      nan      nan
# AAB의 소곱창 전골 800g 8팩                18666.000 7375.000  ... 2071.000 1800.000
# AAC 한우소머니 양곰탕                            nan   97.000  ...      nan      nan
# AAC 한우소머리 곰탕                             nan  350.000  ...      nan      nan
# AAC 한우소머리 곰탕 양곰탕세트                       nan 1204.000  ...      nan      nan
# AAD 남성 소가죽 구름 샌들                    1762.000      nan  ...      nan      nan
# AAD 도트펀칭 컴포트 슬립온                         nan      nan  ... 4697.000 3267.000
# AAD 소가죽 올데이슬립온                      2666.000 2023.000  ...      nan      nan
# AAD 소가죽 투웨이 샌들                      3833.000 3071.000  ...      nan 7618.000
# AAD 여성 소가죽 구름 샌들                    5183.000      nan  ...      nan      nan
# AAE LA 갈비 7팩                             nan      nan  ...      nan      nan
# AHC 스킨케어링 톤커버크림                      851.000  698.000  ...      nan      nan
# BBC&IZUMI 여성 레이스런닝 브라 패키지                nan      nan  ...      nan      nan
# CERINI by PAT 남성 기모 릴렉스팬츠                nan      nan  ...      nan      nan
# CERINI by PAT 남성 기모집업니트 3종               nan      nan  ...      nan      nan
# CERINI by PAT 남성 니트 스웨터 4종           987.000      nan  ...  791.000      nan
# CERINI by PAT 남성 소프트 기모 릴렉스 팬츠      2569.000      nan  ...      nan      nan
# CERINI by PAT 남성 스프링 릴렉스 팬츠 3종           nan      nan  ...      nan      nan
# CERINI by PAT 남성 썸머 쿨 카라 티셔츠 5종          nan      nan  ...      nan 2656.000
# CERINI by PAT 남성 어반 릴렉스 팬츠 3종            nan      nan  ...      nan      nan
# CERINI by PAT 남성 어반 카라 티셔츠 4종            nan 1787.000  ...      nan      nan
# CERINI by PAT 남성 에어 카라티셔츠 4종             nan      nan  ...      nan      nan
# CERINI by PAT 남성 에어 카타티셔츠 4종             nan      nan  ...      nan      nan
# CERINI by PAT 남성 여름 에어윈디 릴렉스 팬츠 3종       nan      nan  ...      nan      nan
# CERINI by PAT 남성 집업니트 4종                 nan      nan  ...      nan      nan
# CERINI by PAT 남성 캐주얼 셔츠 4종               nan      nan  ...      nan      nan
# CERINI by PAT 남성 풀패키지 기모니트 3종            nan      nan  ...      nan      nan
# DIOR 선글라스(SIDERAL)                       nan      nan  ...      nan      nan
# EXR 남성 리버시블 자켓                           nan      nan  ...      nan      nan
# EXR 남성 멀티패키지 세트 3종                       nan  331.000  ...      nan      nan
# EXR 남성 워터 액티비티 5종                        nan  494.000  ...      nan      nan
# EXR 남성 퍼포먼스 패딩 점퍼                        nan      nan  ...      nan      nan
# EXR 여성 리버시블 자켓                           nan      nan  ...      nan      nan
# CERINI by PAT 남성 집업니트 4종                 nan        nan       nan 1400.000
# CERINI by PAT 남성 캐주얼 셔츠 4종               nan        nan       nan 4668.000
# CERINI by PAT 남성 풀패키지 기모니트 3종            nan        nan       nan      nan
# DIOR 선글라스(SIDERAL)                       nan        nan       nan      nan
# EXR 남성 리버시블 자켓                           nan        nan       nan      nan
# EXR 남성 멀티패키지 세트 3종                       nan        nan       nan      nan
# EXR 남성 워터 액티비티 5종                        nan        nan       nan      nan
# EXR 남성 퍼포먼스 패딩 점퍼                        nan        nan       nan      nan
# EXR 여성 리버시블 자켓                           nan        nan       nan      nan
# EXR 여성 멀티패키지 세트 3종                       nan        nan       nan      nan
# EXR 여성 워터 액티비티 5종                        nan        nan       nan      nan
# EXR 여성 퍼포먼스 패딩 점퍼                        nan        nan       nan      nan
# IH 옛 가마솥 세트                         4121.000        nan       nan      nan
# K-SWISS 남성 PK티셔츠 4종                      nan        nan       nan      nan
# K-SWISS 남성 기모티셔츠 5종                      nan        nan       nan      nan
# K-SWISS 남성 벤치코트                          nan        nan       nan      nan
# K-SWISS 남성 아웃도어 팬츠 3종                221.000        nan       nan      nan
# K-SWISS 남성 약기모 팬츠 3종                     nan        nan  1508.000  934.000
# K-SWISS 남성 약기모팬츠 3종                      nan        nan       nan  772.000
# K-SWISS 남성 에어핏 트랙수트                      nan        nan       nan      nan
# K-SWISS 남성 에어핏트랙수트                       nan        nan       nan 2018.000
# K-SWISS 남성 웜테크 벤치코트                      nan        nan       nan  946.000
#
# 방송시간                                     20       21       22       23
# NEW상품명
# 100% 리얼 착즙 석류 4박스                       nan      nan      nan      nan
# 3D매쉬 냉수마찰 물매트                           nan      nan      nan      nan
# AAA 남성 트레킹화 3종                          nan      nan      nan      nan
# AAA 여성 트레킹화 3종                          nan      nan      nan      nan
# AAB의 든든한 콩국수                            nan      nan      nan      nan
# AAB의 소곱창 전골 800g 8팩                4223.000 1448.000  986.000      nan
# AAC 한우소머니 양곰탕                           nan      nan      nan      nan
# AAC 한우소머리 곰탕                            nan      nan      nan      nan
# AAC 한우소머리 곰탕 양곰탕세트                      nan      nan      nan      nan
# AAD 남성 소가죽 구름 샌들                        nan      nan      nan      nan
# AAD 도트펀칭 컴포트 슬립온                        nan      nan      nan      nan
# AAD 소가죽 올데이슬립온                          nan      nan      nan      nan
# AAD 소가죽 투웨이 샌들                     4042.000      nan      nan      nan
# AAD 여성 소가죽 구름 샌들                        nan      nan      nan      nan
# AAE LA 갈비 7팩                            nan      nan      nan      nan
# AHC 스킨케어링 톤커버크림                         nan      nan      nan      nan
# BBC&IZUMI 여성 레이스런닝 브라 패키지               nan  618.000  172.000 2005.000
# CERINI by PAT 남성 기모 릴렉스팬츠               nan      nan      nan      nan
# CERINI by PAT 남성 기모집업니트 3종              nan      nan      nan      nan
# CERINI by PAT 남성 니트 스웨터 4종              nan      nan      nan      nan
# CERINI by PAT 남성 소프트 기모 릴렉스 팬츠          nan 6952.000      nan 2147.000
# CERINI by PAT 남성 스프링 릴렉스 팬츠 3종     6193.000 1240.000      nan  882.000
# CERINI by PAT 남성 썸머 쿨 카라 티셔츠 5종         nan      nan      nan      nan
# CERINI by PAT 남성 어반 릴렉스 팬츠 3종           nan      nan      nan      nan
# CERINI by PAT 남성 어반 카라 티셔츠 4종           nan      nan      nan 1568.000
# CERINI by PAT 남성 에어 카라티셔츠 4종            nan      nan      nan      nan
# CERINI by PAT 남성 에어 카타티셔츠 4종            nan      nan      nan      nan
# CERINI by PAT 남성 여름 에어윈디 릴렉스 팬츠 3종 1527.000      nan      nan      nan
# CERINI by PAT 남성 집업니트 4종                nan      nan      nan      nan
# CERINI by PAT 남성 캐주얼 셔츠 4종          623.000      nan      nan      nan
# CERINI by PAT 남성 풀패키지 기모니트 3종           nan      nan      nan      nan
# DIOR 선글라스(SIDERAL)                      nan      nan      nan      nan
# EXR 남성 리버시블 자켓                          nan      nan      nan      nan
# EXR 남성 멀티패키지 세트 3종                      nan      nan      nan      nan
# EXR 남성 워터 액티비티 5종                       nan      nan      nan      nan
# EXR 남성 퍼포먼스 패딩 점퍼                       nan      nan      nan      nan
# EXR 여성 리버시블 자켓                          nan      nan      nan      nan
# EXR 여성 멀티패키지 세트 3종                      nan      nan      nan      nan
# EXR 여성 워터 액티비티 5종                       nan      nan      nan      nan
# EXR 여성 퍼포먼스 패딩 점퍼                       nan      nan      nan      nan
# IH 옛 가마솥 세트                             nan      nan      nan      nan
# K-SWISS 남성 PK티셔츠 4종                     nan      nan      nan  981.000
# K-SWISS 남성 기모티셔츠 5종                     nan      nan      nan 1018.000
# K-SWISS 남성 벤치코트                         nan      nan      nan      nan
# K-SWISS 남성 아웃도어 팬츠 3종               161.000      nan      nan      nan
# K-SWISS 남성 약기모 팬츠 3종                    nan      nan      nan      nan
# K-SWISS 남성 약기모팬츠 3종                     nan      nan      nan      nan
# K-SWISS 남성 에어핏 트랙수트                     nan 1286.000      nan      nan
# K-SWISS 남성 에어핏트랙수트                  879.000 1239.000 1724.000 1305.000
# K-SWISS 남성 웜테크 벤치코트                 816.000      nan      nan      nan
#
# [50 rows x 21 columns]

# %%
pd.pivot_table(sale, index = '상품군', columns = '방송월', values = '판매량01', aggfunc = np.mean).T.reset_index()
# Out:
# 상품군  방송월     가구     가전    건강기능      농수축    무형    생활용품      속옷      의류     이미용  \
# 0      1    nan 16.060 223.095  939.365 0.000 255.373 348.560 311.944 885.581
# 1      2 22.850 16.447 377.359  931.847 0.000 242.468 221.562 365.883 782.789
# 2      3 17.336 13.691 361.767  873.856 0.000 291.557 271.208 314.484 859.473
# 3      4 16.043 10.907 320.351  941.578 0.000 166.069 367.310 363.860 714.286
# 4      5 14.774 11.348 274.167  925.267 0.000 218.547 452.833 432.837 839.358
# 5      6 15.140 13.523 458.644  981.081 0.000 304.833 431.297 417.326 813.386
# 6      7 18.758 14.020 409.159  928.225 0.000 152.562 334.398 464.096 782.589
# 7      8 19.082 17.194 266.479  965.266 0.000 106.270 538.045 575.944 491.321
# 8      9 22.015 19.009 384.753  987.361 0.000 139.324 273.143 292.472 637.667
# 17  1356.842 128.164 111.366     nan
# 18  1731.212 204.655 124.878 187.500
# 19  1482.522 137.130  96.306 244.833
# 20   801.386 142.148 115.032 105.704

# %%
pd.pivot_table(sale, index = '상품군', columns = '방송시간(분))', values = '판매량01', aggfunc = np.mean).T.reset_index()
# Out:
# 상품군  방송시간(분))     가구     가전    건강기능      농수축    무형    생활용품      속옷      의류  \
# 0           0 13.048 12.200 303.153  792.737 0.000 136.948 273.263 288.507
# 1           5    nan 29.042     nan 1050.000   nan     nan     nan     nan
# 2          10    nan    nan     nan  880.905   nan 256.200 421.452  57.283
# 3          15    nan 17.292     nan  612.167   nan     nan     nan     nan
# 4          20 15.534 13.764 354.275  963.700 0.000 161.428 328.253 390.907
# 5          30  5.318 10.651 172.333  791.516 0.000 165.287 688.223 248.141
# 6          35    nan 15.083     nan  796.000   nan     nan     nan     nan
# 7          40 25.487 21.578 469.616 1167.815 0.000 229.824 425.525 518.489
# 8          45    nan 28.833     nan  799.000   nan     nan     nan     nan
# 9          50  6.538 20.803 198.500 1060.636 0.000 201.450 707.472 157.039
#
# 상품군     이미용       잡화      주방      침구
# 0   709.007  155.646 139.846  99.325
# 1       nan 1026.000     nan     nan
# 2   194.500  356.118     nan     nan
# 3       nan      nan     nan     nan
# 4   746.075  278.892 172.568 158.019
# 5   896.762   49.419 380.005 115.267
# 6       nan  839.000     nan     nan
# 7   959.210  407.464 244.063 212.498
# 8       nan      nan     nan     nan
# 9   254.250   92.318 341.583     nan

# %% [markdown]
# # 2. 데이터 통합

# %%
sale = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'sale_data_v05_0828.xlsx'))
meta = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'sale_meta_v04_0823.xlsx'))
item = pd.read_excel(os.path.join('..', '..', '0.Data', '01_제공데이터', 'item_meta_v04_0828.xlsx'))

# %%
sale.shape, meta.shape, item.shape
# Out:
# ((38309, 16), (2042, 15), (1364, 15))

# %%
sale = FE.engineering_TimeDiff(sale)

# %%
sale = FE.engineering_Soldout(sale)

# %%
sale = FE.engineering_DatePrice(sale)
# Out:
# 연도입력
#  2019

# %%
sale = FE.engineering_trendnorder(sale)
# Out:
# /Users/jinseok/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/polynomial.py:630: RuntimeWarning: invalid value encountered in true_divide
#   lhs /= scale

# %%
emb = pd.read_excel(os.path.join('..', '..', '0.Data', '04_임베딩데이터', 'version3_dim30.xlsx'), index_col = 0)
sale = sale.merge(emb.drop_duplicates(), on = 'NEW상품명', how = 'left')

# %%
sale.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00 20.000  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00 20.000  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00 20.000  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00 20.000  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00 20.000  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#           취급액  NEW상품코드          NEW상품명  ...    v20    v21   v22    v23    v24  \
# 0 2099000.000  865.000  테이트 남성 셀린니트 3종  ... -0.002 -0.013 0.005  0.002 -0.002
# 1 4371000.000  866.000  테이트 여성 셀린니트 3종  ...  0.001 -0.010 0.009 -0.004 -0.008
# 2 3262000.000  865.000  테이트 남성 셀린니트 3종  ... -0.002 -0.013 0.005  0.002 -0.002
# 3 6955000.000  866.000  테이트 여성 셀린니트 3종  ...  0.001 -0.010 0.009 -0.004 -0.008
# 4 6672000.000  865.000  테이트 남성 셀린니트 3종  ... -0.002 -0.013 0.005  0.002 -0.002
#
#      v25    v26   v27   v28    v29
# 0 -0.001 -0.002 0.001 0.001 -0.003
# 1 -0.003 -0.004 0.004 0.002 -0.006
# 2 -0.001 -0.002 0.001 0.001 -0.003
# 3 -0.003 -0.004 0.004 0.002 -0.006
# 4 -0.001 -0.002 0.001 0.001 -0.003
#
# [5 rows x 130 columns]

# %%
df_eco = pd.read_excel(os.path.join('..', '..', '0.Data', '03_외부데이터', '전처리', 'prep_1차외부데이터_0901.xlsx'))
df_wth = pd.read_csv(os.path.join('..', '..', '0.Data', '03_외부데이터', '전처리', 'prep_2019_pb_weather.csv'), encoding = 'cp949')
df_dust = pd.read_csv(os.path.join('..', '..', '0.Data', '03_외부데이터', '전처리', 'prep_2019_pb_dust.csv'), encoding = 'cp949')

# %%
data = sale.merge(df_eco[df_eco['년도'] == 2019], left_on = '방송월', right_on = '월', how = 'left').drop(['날짜', '월'], axis = 1)

# %%
data = data.merge(df_wth, left_on = ['방송월', '방송일', '방송시간(시간)'], right_on = ['월', '일', '시간'], how ='left').drop(['날짜', '월', '일', '시간'], axis = 1)

# %%
data = data.merge(df_dust, left_on = ['방송월', '방송일', '방송시간(시간)'], right_on = ['월', '일', '시간'], how ='left').drop(['날짜', '월', '일', '시간'], axis = 1)

# %%
categorys = ['결제방법', '상품군_가격대', '전체_가격대', '상품군', '방송시간(시간)', '성별']
drop_columns = ['방송일시','마더코드', '상품코드', '상품명', 'NEW상품코드', 'NEW상품명', '단위', '브랜드', '취급액', '상품코드', '옵션', '종류', '년도', '상품명다시', '방송날짜']

# %%
data[categorys] = data[categorys].astype(str)

# %%
# 예측 상품 중 판매가 0인 프로그램 실적은 예측에서 제외함 -> 무형 제외
data = data.loc[data['상품군'] != '무형']

# %%
# 주문이 0인, 취급액이 0인 데이터 제외함
data = data.loc[data['취급액'].notnull()]

# %%
y = data['취급액']
drop_data = data[drop_columns]
data = data.drop(drop_columns, axis = 1)

# %%
data['log최근3개월상품군추세'] = data['log최근3개월상품군추세'].astype(float)

# %%
X = pd.get_dummies(data)

# %%
pd.DataFrame(X.columns).to_excel('./test.xlsx')

# %%
X.shape, y.shape
# Out:
# ((35379, 518), (35379,))

# %%
import joblib
joblib.dump({
    'X' : X,
    'y' : y
}, os.path.join('..', '..', '0.Data', '05_분석데이터', 'Thd_FE.pkl'))
# Out:
# ['../../0.Data/05_분석데이터/Thd_FE.pkl']
