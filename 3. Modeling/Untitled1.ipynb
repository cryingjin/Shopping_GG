# %%
import os
import sys
import math
import gc
import random
import joblib
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings(action='ignore')

# %%
aelog = pd.read_excel(os.path.join('..', '..', '0.Data', '04_임시데이터', 'autoencoder_logdf.xlsx'))
ae = pd.read_excel(os.path.join('..', '..', '0.Data', '04_임시데이터', 'autoencoder_X.xlsx'))

# %%
aelog
# Out:
#      user      100000      100001      100002      100006      100009  \
# 0     1-0  229.913864  588.656860  812.614380  450.895508  546.106873
# 1     1-1  228.676773  583.802979  807.480286  448.338928  542.832092
# 2    1-10  230.316132  591.899414  817.484131  453.168884  552.371460
# 3    1-11  230.277603  590.337097  811.527222  451.447906  547.056702
# 4    1-12  230.943558  591.856689  817.008545  452.475403  551.219482
# ..    ...         ...         ...         ...         ...         ...
# 235  9-23  229.577179  587.220032  807.473999  449.111145  545.672241
# 236   9-6  231.094894  588.922607  813.784180  452.479675  547.567810
# 237   9-7  231.341873  591.164978  817.922974  454.263550  550.730652
# 238   9-8  230.891159  590.079773  813.123169  452.060364  548.484741
# 239   9-9  231.308395  591.680786  819.042786  454.322021  551.678772
#
#           100010      100013      100015      100016  ...      100837  \
# ...

# %%
ae
# Out:
#      user      100000      100001      100002      100006      100009  \
# 0     1-0  104.002968  338.177368  391.945892  235.903198  209.713776
# 1     1-1  106.134567  246.770309  335.967255  209.928101  212.147614
# 2    1-10   94.475151  521.482910  613.752563  336.480743  641.419495
# 3    1-11  128.440109  431.588745  204.083801  251.951736  190.608337
# 4    1-12  145.684753  501.607269  503.419220  266.147827  473.688568
# ..    ...         ...         ...         ...         ...         ...
# 235  9-23  139.572968  357.326385  531.312561  314.757782  457.038757
# 236   9-6  198.742950  418.469116  584.823120  381.052490  367.010895
# 237   9-7  181.334015  489.939819  717.060974  431.695557  491.604919
# 238   9-8  128.657486  342.387665  218.807190  251.655396  259.666443
# 239   9-9  189.699753  507.552338  724.328186  438.992615  516.429199
#
#           100010      100013      100015      100016  ...      100837  \
# ...
