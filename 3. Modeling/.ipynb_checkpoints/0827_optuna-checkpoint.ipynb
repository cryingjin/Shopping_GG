# %%
import os
import sys
import joblib

import pandas as pd 
import numpy as np
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

import imp
import datetime
from tqdm import tqdm

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
plt.rc('font', family='NanumBarunGothic')
plt.rc('axes', unicode_minus=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# 코랩 한글 설치 
# import matplotlib as mpl
# import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
# import matplotlib.font_manager as fm
# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# plt.rc('font', family='NanumBarunGothic') 
# mpl.font_manager._rebuild()
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144556 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# plt.figure(figsize=(5,5))
# plt.plot([0,1], [0,1], label='한글테스트용')
# plt.legend()
# plt.show()

# %% [markdown]
# ### git clone Mecab

# %%
# ! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# cd Mecab-ko-for-Google-Colab
# ! bash install_mecab-ko_on_colab190912.sh

# %%
from konlpy.tag import Mecab
from gensim.models import Word2Vec, fasttext

# %% [markdown]
# ### git clone Shopping_GG

# %%
cd ..
# Out:
# /content

# %%
user = 'jbeen2'
password = '?!'

# !git clone https://{user}:{password}@github.com/cryingjin/Shopping_GG.git
# Out:
# Cloning into 'Shopping_GG'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 283 (delta 58), reused 57 (delta 14), pack-reused 158
# Receiving objects: 100% (283/283), 28.20 MiB | 1.93 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
cd /content/Shopping_GG
# Out:
# /content/Shopping_GG

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/cryingjin/Shopping_GG
#  * branch            master     -> FETCH_HEAD
#    c30f2ac..81f9fd7  master     -> origin/master
# Updating c30f2ac..81f9fd7
# Fast-forward
#  2. FE/FE_0826.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# # Data Load

# %%
sale = pd.read_excel(os.path.join('0.Data', '01_제공데이터', 'sale_data_v04_0823.xlsx'), encoding="utf-8")
meta = pd.read_excel(os.path.join('0.Data', '01_제공데이터', 'sale_meta_v04_0823.xlsx'), encoding="utf-8")
item = pd.read_excel(os.path.join('0.Data', '01_제공데이터', 'item_meta_v03_0823.xlsx'), encoding="utf-8")

# %%
sale.shape, meta.shape, item.shape
# Out:
# ((38309, 15), (2042, 15), (1364, 12))

# %%
sale.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액  NEW상품코드          NEW상품명  결제방법  단위  브랜드   옵션 종류
# 0  2099000.0    865.0  테이트 남성 셀린니트 3종   0.0  3종  테이트  NaN  0
# 1  4371000.0    866.0  테이트 여성 셀린니트 3종   0.0  3종  테이트  NaN  0
# 2  3262000.0    865.0  테이트 남성 셀린니트 3종   0.0  3종  테이트  NaN  0
# 3  6955000.0    866.0  테이트 여성 셀린니트 3종   0.0  3종  테이트  NaN  0
# 4  6672000.0    865.0  테이트 남성 셀린니트 3종   0.0  3종  테이트  NaN  0

# %%
# 무형 데이터 처리 : 동일 상품명으로 채워줌 
# preprocessing.py 만들어서 넣어야 할듯...? 

sale["NEW상품명"] = sale["NEW상품명"].fillna(sale["상품명"])

# %% [markdown]
# # Feature Engineering

# %%
cd 2. FE
# Out:
# /content/Shopping_GG/2. FE

# %%
import FE_0826 as FE

# %%
imp.reload(FE)
# Out:
# <module 'FE_0826' from '/content/Shopping_GG/2. FE/FE_0826.py'>

# %%
# 민정
# meta_ver1 = FE.FE_NLP_MJ.product_name_embedding_ver1(meta) # v129
meta_ver2 = FE.FE_NLP_MJ.product_name_embedding_ver2(meta) # v9

# %%
sale2 = pd.merge(sale, meta_ver2.drop(['상품코드', '상품명', '상품군', '판매단가', '결제방법', 
                                       '상품명다시', '단위', '브랜드', '옵션', '종류', '모델명', '성별', 
                                       'NEW상품코드', '마더코드'], axis=1).drop_duplicates(), on="NEW상품명", how='left')

# %%
sale2.shape
# Out:
# (38309, 25)

# %%
# 재빈
sale2 = FE.FE_product_timelag_JB.broadcast_count(sale2)
sale2 = FE.FE_product_timelag_JB.sales_count(sale2)

# %%
# 예진
sale2 = FE.FE_sold_out_fill_time_YJ.sold_out_fill_time(sale2)

# %%
# 진석 
sale2 = FE.FE_dateprice_JS.preprocessing(sale2)
# Out:
# 연도입력
# 2019

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### 무형 상품군 제외

# %%
sale2 = sale2.loc[sale2["상품군"] != "무형"]
sale2.shape
# Out:
# (37372, 70)

# %% [markdown]
# ### isHoliday

# %%
sale2["isHoliday"] = sale2["isHoliday"].map(lambda x : 1 if x == 'Y' else 0)
sale2["isHoliday"].value_counts()
# Out:
# 0    35576
# 1     1796
# Name: isHoliday, dtype: int64

# %% [markdown]
# ### 취급액

# %%
sale2["취급액"] = sale2["취급액"].fillna(1e-5)

# %% [markdown]
# ### 상품군 & 브랜드 결측값

# %%
sale2 = sale2.fillna(0)

# %% [markdown]
# ### 더미화

# %%
category = ['결제방법', '상품군_가격대', '전체_가격대', '상품군', '방송시간(시간)']

drop_columns = ['방송일시', '상품명', '마더코드', '상품코드', 
                'NEW상품코드', 'NEW상품명', '옵션', '종류', '단위', '브랜드', 'locdate',                 
                '취급액']

# %%
for c in category:
    sale2[c] = sale2[c].astype(str)

# %% [markdown]
# ### ver2

# %%
sale3 = sale2.loc[sale2["취급액"] > 1]
sale3.shape
# Out:
# (35379, 70)

# %%
y = sale3['취급액']
temp = sale3[drop_columns]
data= sale3.drop(drop_columns, axis = 1)

# %%
# 로그변환
y = np.log1p(y)

# %%
X = pd.get_dummies(data)
X.shape, y.shape
# Out:
# ((35379, 109), (35379,))

# %%
figure, (ax1, ax2) = plt.subplots(ncols=2)
figure.set_size_inches(12,4)

sns.boxplot(y, ax=ax1)
sns.distplot(y, ax=ax2)

# %% [markdown]
# # Modeling

# %%
import random

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
# !pip install optuna
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
# !pip install category_encoders
# !pip install catboost

from category_encoders import OrdinalEncoder, OneHotEncoder, CatBoostEncoder

from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import LinearSVR

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ## xgboost

# %%
from sklearn.model_selection import train_test_split

# %%
def objective(trial):
    data, target = X, y
    train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.3)

    param = {
        'lambda': trial.suggest_loguniform('lambda', 1e-8, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-8, 1.0),
        'max_depth': trial.suggest_int('max_depth', 1, 9),
        'eta': trial.suggest_uniform('eta', 0.03, 1),
        'gamma': trial.suggest_loguniform('gamma', 1e-8, 1.0),
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide']),
        'subsample': trial.suggest_uniform('subsample', 1e-8, 1.0),  # 1.0
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 1e-8, 1.0),  # 1.0
        'colsample_bylevel': trial.suggest_uniform('colsample_bylevel', 1e-8, 1.0),  # 1.0
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-8, 10.0),  # 1.0
        'max_bin': trial.suggest_int('max_bin', 63, 256),  # 256
        'predictor': 'gpu_predictor',
        'nthread': 8,
        'objective': 'reg:squarederror',
        'eval_metric' : 'mae',
        'n_estimators': 100000,
        'seed': 0
    }

    gbm = XGBRegressor(**param)

    gbm.fit(train_x, train_y, eval_set=[(valid_x, valid_y)], verbose=0, early_stopping_rounds=100)

    preds = gbm.predict(valid_x)
    mape = mean_absolute_percentage_error(valid_y, preds)
    return mape


if __name__ == "__main__":
    study = optuna.create_study()
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 15
# Best trial:
#   Value: 1.7864082294706694
#   Params:
#     lambda: 9.585132902737473e-06
#     alpha: 0.4390340939708635
#     max_depth: 9
#     eta: 0.9970893538848524
#     gamma: 5.008935378569622e-06
#     grow_policy: depthwise
#     subsample: 0.9911038679166915
#     colsample_bytree: 0.6288556026903691
#     colsample_bylevel: 0.6170074577138729
#     min_child_weight: 9.112742590461542
#     max_bin: 70

# %%
optuna.importance.get_param_importances(study) # hyperparameter 중요도
# Out:
# OrderedDict([('subsample', 0.31961324986180023),
#              ('colsample_bytree', 0.21248765826295535),
#              ('colsample_bylevel', 0.1856010547043089),
#              ('max_depth', 0.1666782168671374),
#              ('gamma', 0.05219122186381082),
#              ('eta', 0.025120448494304327),
#              ('alpha', 0.01591245224768737),
#              ('grow_policy', 0.014008778907780359),
#              ('max_bin', 0.00715471230662208),
#              ('lambda', 0.0011629252119849465),
#              ('min_child_weight', 6.928127160811191e-05)])

# %%
xgb_params = {
            'nthread': -1, 'booster' : 'gbtree', 'silent': 1, 
            'predictor': 'gpu_predictor', 'objective': 'reg:linear', 'eval_metric' : 'mae', 
            'lambda': 9.585132902737473e-06,
            'alpha': 0.4390340939708635,
            'max_depth': 9,
            'eta': 0.9970893538848524,
            'gamma': 5.008935378569622e-06,
            'grow_policy': 'depthwise',
            'subsample': 0.9911038679166915,
            'colsample_bytree': 0.6288556026903691,
            'colsample_bylevel': 0.6170074577138729,
            'min_child_weight': 9.112742590461542,
            'max_bin': 70,        
            }

# %%
preds = []
feat_imp = dict()
for col in X.columns : 
    feat_imp[col] = 0


for i in range(1,13):
    # 한달에서도 랜덤 샘플 반 뽑기
    test_idx = random.sample(list(X[X['방송월'] == i].index), int(len(X[X['방송월'] == i]) / 2))
    train_idx = set(X.index) - set(test_idx)
    
    train = X.loc[train_idx]
    test = X.loc[test_idx]
    y_test = y.loc[test_idx]
    
    x_train = train[train['방송월'] != i].values
    y_train = y.loc[train[train['방송월'] != i].index].values
    
    x_val = train[train['방송월'] == i].values
    y_val = y.loc[train[train['방송월'] == i].index].values


    gbm = XGBRegressor(**xgb_params)

    gbm.fit(x_train, y_train, eval_set=[(x_val, y_val)], verbose=10, early_stopping_rounds=100)

    preds = gbm.predict(test.values)
    mape = mean_absolute_percentage_error(y_test, preds)
    print(mape)


#     for key, value in gbm.get_score(importance_type='gain').items() : 
#         feat_imp[key] += value

#     print(preds)
# print(np.mean(preds))
# Out:
# [0]	validation_0-mae:14.5019
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.06786
# [20]	validation_0-mae:1.79768
# [30]	validation_0-mae:0.760956
# [40]	validation_0-mae:0.486633
# [50]	validation_0-mae:0.421357
# [60]	validation_0-mae:0.399298
# [70]	validation_0-mae:0.391741
# [80]	validation_0-mae:0.388323
# [90]	validation_0-mae:0.387887
# [99]	validation_0-mae:0.385461
# 2.4258287592175125
# [0]	validation_0-mae:14.3845
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:4.99366
# [20]	validation_0-mae:1.74257
# [30]	validation_0-mae:0.701532
# [40]	validation_0-mae:0.447831
# [50]	validation_0-mae:0.39419
# [60]	validation_0-mae:0.380922
# [70]	validation_0-mae:0.376938
# [80]	validation_0-mae:0.371514
# [90]	validation_0-mae:0.370065
# [99]	validation_0-mae:0.367159
# 2.267056514161064
# [0]	validation_0-mae:14.3679
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:4.97876
# [20]	validation_0-mae:1.72861
# [30]	validation_0-mae:0.703085
# [40]	validation_0-mae:0.459833
# [50]	validation_0-mae:0.415537
# [60]	validation_0-mae:0.405261
# [70]	validation_0-mae:0.399909
# [80]	validation_0-mae:0.396908
# [90]	validation_0-mae:0.394877
# [99]	validation_0-mae:0.394033
# 2.3958866020789613
# [0]	validation_0-mae:14.3257
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:4.95624
# [20]	validation_0-mae:1.69665
# [30]	validation_0-mae:0.639363
# [40]	validation_0-mae:0.398376
# [50]	validation_0-mae:0.361905
# [60]	validation_0-mae:0.355224
# [70]	validation_0-mae:0.351754
# [80]	validation_0-mae:0.348554
# [90]	validation_0-mae:0.347491
# [99]	validation_0-mae:0.346925
# 2.269031054856671
# [0]	validation_0-mae:14.3868
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.02261
# [20]	validation_0-mae:1.77357
# [30]	validation_0-mae:0.740327
# [40]	validation_0-mae:0.480194
# [50]	validation_0-mae:0.421006
# [60]	validation_0-mae:0.406406
# [70]	validation_0-mae:0.397769
# [80]	validation_0-mae:0.393944
# [90]	validation_0-mae:0.388771
# [99]	validation_0-mae:0.387438
# 2.359823258091149
# [0]	validation_0-mae:14.4925
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.10074
# [20]	validation_0-mae:1.8099
# [30]	validation_0-mae:0.742061
# [40]	validation_0-mae:0.456325
# [50]	validation_0-mae:0.385386
# [60]	validation_0-mae:0.366156
# [70]	validation_0-mae:0.358166
# [80]	validation_0-mae:0.352499
# [90]	validation_0-mae:0.348201
# [99]	validation_0-mae:0.344599
# 2.1242546727378677
# [0]	validation_0-mae:14.3873
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:4.99182
# [20]	validation_0-mae:1.73381
# [30]	validation_0-mae:0.698826
# [40]	validation_0-mae:0.445192
# [50]	validation_0-mae:0.393517
# [60]	validation_0-mae:0.380926
# [70]	validation_0-mae:0.373958
# [80]	validation_0-mae:0.369565
# [90]	validation_0-mae:0.367723
# [99]	validation_0-mae:0.364801
# 2.10693836249678
# [0]	validation_0-mae:14.5005
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.05564
# [20]	validation_0-mae:1.76933
# [30]	validation_0-mae:0.70619
# [40]	validation_0-mae:0.452294
# [50]	validation_0-mae:0.403426
# [60]	validation_0-mae:0.387559
# [70]	validation_0-mae:0.379149
# [80]	validation_0-mae:0.373409
# [90]	validation_0-mae:0.369736
# [99]	validation_0-mae:0.367822
# 2.3705208305917473
# [0]	validation_0-mae:14.4011
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.00059
# [20]	validation_0-mae:1.75675
# [30]	validation_0-mae:0.719846
# [40]	validation_0-mae:0.459596
# [50]	validation_0-mae:0.406568
# [60]	validation_0-mae:0.392521
# [70]	validation_0-mae:0.384
# [80]	validation_0-mae:0.379027
# [90]	validation_0-mae:0.376783
# [99]	validation_0-mae:0.374392
# 2.3687793374427
# [0]	validation_0-mae:14.4641
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.04613
# [20]	validation_0-mae:1.71425
# [30]	validation_0-mae:0.762938
# [40]	validation_0-mae:0.617828
# [50]	validation_0-mae:0.600791
# [60]	validation_0-mae:0.599293
# [70]	validation_0-mae:0.598619
# [80]	validation_0-mae:0.597328
# [90]	validation_0-mae:0.595429
# [99]	validation_0-mae:0.595248
# 3.7164600272240347
# [0]	validation_0-mae:14.6044
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.12804
# [20]	validation_0-mae:1.83806
# [30]	validation_0-mae:0.771478
# [40]	validation_0-mae:0.51534
# [50]	validation_0-mae:0.455276
# [60]	validation_0-mae:0.43909
# [70]	validation_0-mae:0.42872
# [80]	validation_0-mae:0.42567
# [90]	validation_0-mae:0.423276
# [99]	validation_0-mae:0.418738
# 2.579033636710688
# [0]	validation_0-mae:14.5684
# Will train until validation_0-mae hasn't improved in 100 rounds.
# [10]	validation_0-mae:5.14826
# [20]	validation_0-mae:1.86365
# [30]	validation_0-mae:0.812035
# [40]	validation_0-mae:0.550739
# [50]	validation_0-mae:0.497435
# [60]	validation_0-mae:0.470617
# [70]	validation_0-mae:0.462543
# [80]	validation_0-mae:0.452695
# [90]	validation_0-mae:0.448292
# [99]	validation_0-mae:0.446332
# 2.599536265761715

# %%
# 수작업 ㅋㅋ..;;;
mape_lst = [2.4258287592175125, 2.267056514161064, 2.3958866020789613, 2.269031054856671, 2.359823258091149, 2.1242546727378677, 
            2.10693836249678, 2.3705208305917473, 2.3687793374427, 3.7164600272240347, 2.579033636710688, 2.599536265761715]

# %%
plt.figure(figsize = (10, 7))
plt.plot(mape_lst)
plt.xlabel('Month', fontsize = 14)
plt.title('MAPE', fontsize = 15)
plt.show()

# %%
from xgboost import plot_importance

plt.rcParams["figure.figsize"] = (12, 20)
plot_importance(gbm,)

# %%
X.columns
# Out:
# Index(['노출(분)', '판매단가', 'v0', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7',
#        ...
#        '분기_3분기', '분기_4분기', '상품군_가격대_0.0', '상품군_가격대_1.0', '상품군_가격대_2.0',
#        '전체_가격대_0.0', '전체_가격대_1.0', '전체_가격대_2.0', '전체_가격대_3.0', '전체_가격대_4.0'],
#       dtype='object', length=109)

# %% [markdown]
# * hyperparameter 튜닝을 했는데 뭔가 엄청 좋아진 것 처럼 보이지는 않는듯 ...?
