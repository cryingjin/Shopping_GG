# %% [markdown]
# ### Parameter Tuning
# * LGBM
# * optuna
# * GPU ver.

# %%
import os
import sys
import joblib
import pickle as pkl

import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore')
warnings.filterwarnings(action='ignore', category=DataConversionWarning)


import pandas as pd 
import numpy as np


from IPython.display import display
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option('display.max_info_columns', 500)

# %%
# visualize
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
plt.rc('font', family='malgun gothic')
plt.rc('axes', unicode_minus=False)

# %%
# !git clone https://github.com/Microsoft/LightGBM
# cd LightGBM
# !mkdir build
# !cmake -DUSE_GPU=1
# !make -j$(nproc)
# !sudo apt-get -y install python-pip
# !sudo -H pip install setuptools pandas numpy scipy scikit-learn -U
# %cd /content/LightGBM/python-package
# !sudo python setup.py install
# !pip3 uninstall scikit-learn
# !pip3 install scikit-learn==0.21.3

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
import BoostingModel as model
import SHAPvalue as SHAP
import optimization as opt

# %%
data_v4 = joblib.load(os.path.join('7th_train_FE.pkl'))
locals().update(data_v4)

# %%
X = data_v4["X"] ; y = data_v4["y"]
X.shape, y.shape
# Out:
# ((35379, 402), (35379,))

# %%
y2 = np.log1p(y)

# %% [markdown]
# ## Modeling

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %% [markdown]
# ### lgbm_params6

# %%
def objective_lgbm(trial, X, y):
    
    params = {
        'num_leaves': int(trial.suggest_loguniform('num_leaves', 8, 64)),  
        'max_depth': trial.suggest_int('max_depth', 8, 64), 
        'min_child_samples': trial.suggest_int('min_child_samples', 16, 64),  
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 1e-3, 5.0),  
        'learning_rate': trial.suggest_uniform('learning_rate', 0.001, 0.01),
        'reg_alpha': trial.suggest_uniform('reg_alpha', 0.01, 1.0), 
        'reg_lambda': trial.suggest_uniform('reg_lambda', 0.01, 1.0), 
        'min_split_gain': trial.suggest_loguniform('min_split_gain', 0.01, 0.05),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0), 
        'boost_from_average': trial.suggest_categorical('boost_from_average', [True, False]), 
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),  
        'subsample_freq': trial.suggest_int('subsample_freq', 0, 7), 
        'max_bin': trial.suggest_int('max_bin', 32, 64),  

        'seed': 77,
        'n_jobs': -1,
        'device_type' : 'gpu', 
        'objective': 'regression',
        'num_iterations': 30000,
        'metric': 'mape',
        'importance_type': 'gain'
    }
    
    mape, pred = opt.lgbm_model(X, y, params, cv_splits=5, scaling="MinMax", epoch=30000)

    return mape['final_mape'][0]

# %%
# %%time

lgbm_study2 = optuna.create_study()
lgbm_study2.optimize(lambda x: objective_lgbm(x, X, y2), timeout=1000, n_jobs=-1)
print(lgbm_study2.best_params, lgbm_study2.best_value)
# Out:
# Training until validation scores don't improve for 500 rounds
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0222207
# [2500]	valid_0's mape: 0.020197
# [5000]	valid_0's mape: 0.020522
# [5000]	valid_0's mape: 0.0190858
# [7500]	valid_0's mape: 0.0197958
# [10000]	valid_0's mape: 0.01939
# [7500]	valid_0's mape: 0.0186492
# [12500]	valid_0's mape: 0.0191581
# [10000]	valid_0's mape: 0.0184756
# [15000]	valid_0's mape: 0.0190184
# [12500]	valid_0's mape: 0.018398
# [17500]	valid_0's mape: 0.0189143
# [15000]	valid_0's mape: 0.0183592
# [20000]	valid_0's mape: 0.0188393
# [17500]	valid_0's mape: 0.0183433
# Early stopping, best iteration is:
# [17841]	valid_0's mape: 0.0183386
# [22500]	valid_0's mape: 0.0187834
# Training until validation scores don't improve for 500 rounds
# [25000]	valid_0's mape: 0.0187404
# Early stopping, best iteration is:
# [25678]	valid_0's mape: 0.0187301
# [2500]	valid_0's mape: 0.0201242
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0221562
# [5000]	valid_0's mape: 0.0189
# [5000]	valid_0's mape: 0.0203552
# [7500]	valid_0's mape: 0.0183831
# [7500]	valid_0's mape: 0.0195617
# [10000]	valid_0's mape: 0.0181519
# [10000]	valid_0's mape: 0.0191122
# [12500]	valid_0's mape: 0.0180396
# [12500]	valid_0's mape: 0.0188243
# [15000]	valid_0's mape: 0.017983
# [15000]	valid_0's mape: 0.0186129
# [17500]	valid_0's mape: 0.0179462
# [17500]	valid_0's mape: 0.0184565
# [20000]	valid_0's mape: 0.0179311
# Early stopping, best iteration is:
# [20004]	valid_0's mape: 0.0179306
# [20000]	valid_0's mape: 0.0183546
# Training until validation scores don't improve for 500 rounds
# [22500]	valid_0's mape: 0.0182752
# [25000]	valid_0's mape: 0.018227
# [2500]	valid_0's mape: 0.0210087
# [27500]	valid_0's mape: 0.0181855
# [5000]	valid_0's mape: 0.0196078
# [30000]	valid_0's mape: 0.0181545
# Did not meet early stopping. Best iteration is:
# [29986]	valid_0's mape: 0.0181539
# [7500]	valid_0's mape: 0.019018
# Training until validation scores don't improve for 500 rounds
# [10000]	valid_0's mape: 0.018763
# [2500]	valid_0's mape: 0.0230527
# [12500]	valid_0's mape: 0.0186309
# [5000]	valid_0's mape: 0.0211573
# [15000]	valid_0's mape: 0.0185605
# [7500]	valid_0's mape: 0.0202702
# [17500]	valid_0's mape: 0.0185253
# [10000]	valid_0's mape: 0.0197472
# [20000]	valid_0's mape: 0.0185086
# [12500]	valid_0's mape: 0.0194229
# [22500]	valid_0's mape: 0.0184972
# Early stopping, best iteration is:
# [23352]	valid_0's mape: 0.0184946
# [15000]	valid_0's mape: 0.0191843
# Training until validation scores don't improve for 500 rounds
# [17500]	valid_0's mape: 0.0190312
# [20000]	valid_0's mape: 0.01892
# [2500]	valid_0's mape: 0.0207767
# [22500]	valid_0's mape: 0.0188326
# [25000]	valid_0's mape: 0.0187776
# [5000]	valid_0's mape: 0.0194018
# [27500]	valid_0's mape: 0.0187288
# [7500]	valid_0's mape: 0.0188724
# [30000]	valid_0's mape: 0.0187016
# Did not meet early stopping. Best iteration is:
# [29985]	valid_0's mape: 0.0187014
# [10000]	valid_0's mape: 0.0186207
# Training until validation scores don't improve for 500 rounds
# [12500]	valid_0's mape: 0.0185083
# [2500]	valid_0's mape: 0.0226725
# [15000]	valid_0's mape: 0.0184434
# [5000]	valid_0's mape: 0.0208864
# [17500]	valid_0's mape: 0.0184159
# [20000]	valid_0's mape: 0.018402
# [7500]	valid_0's mape: 0.0200618
# [22500]	valid_0's mape: 0.0183921
# Early stopping, best iteration is:
# [22644]	valid_0's mape: 0.0183909
# [10000]	valid_0's mape: 0.0195857
# [12500]	valid_0's mape: 0.0193098
# Training until validation scores don't improve for 500 rounds
# [15000]	valid_0's mape: 0.0191173
# [2500]	valid_0's mape: 0.0202917
# [17500]	valid_0's mape: 0.0189778
# [20000]	valid_0's mape: 0.0188685
# [5000]	valid_0's mape: 0.0191571
# [22500]	valid_0's mape: 0.0187927
# [7500]	valid_0's mape: 0.0187692
# [25000]	valid_0's mape: 0.0187466
# [10000]	valid_0's mape: 0.0185997
# [27500]	valid_0's mape: 0.0187079
# [30000]	valid_0's mape: 0.0186806
# Did not meet early stopping. Best iteration is:
# [29906]	valid_0's mape: 0.0186799
# [12500]	valid_0's mape: 0.0185253
# [15000]	valid_0's mape: 0.0184986
# Training until validation scores don't improve for 500 rounds
# [17500]	valid_0's mape: 0.0184923
# Early stopping, best iteration is:
# [17808]	valid_0's mape: 0.0184901
# [2500]	valid_0's mape: 0.0222664
# [5000]	valid_0's mape: 0.0205678
# [7500]	valid_0's mape: 0.0198809
# [10000]	valid_0's mape: 0.0195045
# [12500]	valid_0's mape: 0.0192844
# [15000]	valid_0's mape: 0.0191529
# [17500]	valid_0's mape: 0.0190667
# [20000]	valid_0's mape: 0.0189946
# [22500]	valid_0's mape: 0.0189418
# [25000]	valid_0's mape: 0.018906
# Early stopping, best iteration is:
# [26315]	valid_0's mape: 0.0188877
# {'num_leaves': 24.599369743870696, 'max_depth': 30, 'min_child_samples': 42, 'min_child_weight': 1.5988122260167432, 'learning_rate': 0.00835697155742915, 'reg_alpha': 0.8797261747326673, 'reg_lambda': 0.49350813300094204, 'min_split_gain': 0.0165654210239466, 'colsample_bytree': 0.9584009927992173, 'boost_from_average': True, 'subsample': 0.9513225021923524, 'subsample_freq': 2, 'max_bin': 58} 32.71684106973882
# CPU times: user 50min 17s, sys: 6min 56s, total: 57min 13s
# Wall time: 29min 57s

# %%
lgbm_params6 = lgbm_study2.best_params.copy()
lgbm_params6['num_leaves'] = int(lgbm_params6['num_leaves'])
lgbm_params6['n_jobs'] = -1
lgbm_params6['device_type'] = 'gpu', 
lgbm_params6['num_iterations'] = 30000
lgbm_params6['objective'] = 'regression'
lgbm_params6['metric'] = 'mape'
lgbm_params6['is_training_metric'] = True
lgbm_params6['verbose'] = -1

# %%
lgbm_params6
# Out:
# {'boost_from_average': True,
#  'colsample_bytree': 0.9584009927992173,
#  'device_type': ('gpu',),
#  'is_training_metric': True,
#  'learning_rate': 0.00835697155742915,
#  'max_bin': 58,
#  'max_depth': 30,
#  'metric': 'mape',
#  'min_child_samples': 42,
#  'min_child_weight': 1.5988122260167432,
#  'min_split_gain': 0.0165654210239466,
#  'n_jobs': -1,
#  'num_iterations': 30000,
#  'num_leaves': 24,
#  'objective': 'regression',
#  'reg_alpha': 0.8797261747326673,
#  'reg_lambda': 0.49350813300094204,
#  'subsample': 0.9513225021923524,
#  'subsample_freq': 2,
#  'verbose': -1}

# %%
# %%time

lgbm_mape6, lgbm_pred6, lgbm_shap6 = SHAP.lgbm_SHAP(X, y2, lgbm_params6, version='0921-lgbm-optuna2', cv_splits=5, scaling="MinMax", epoch=30000)
# Out:
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0202573
# [5000]	valid_0's mape: 0.019106
# [7500]	valid_0's mape: 0.018662
# [10000]	valid_0's mape: 0.018475
# [12500]	valid_0's mape: 0.0183925
# [15000]	valid_0's mape: 0.0183653
# Early stopping, best iteration is:
# [16474]	valid_0's mape: 0.0183516
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0201943
# [5000]	valid_0's mape: 0.0189757
# [7500]	valid_0's mape: 0.0184468
# [10000]	valid_0's mape: 0.0181995
# [12500]	valid_0's mape: 0.018081
# [15000]	valid_0's mape: 0.0180178
# [17500]	valid_0's mape: 0.0179847
# [20000]	valid_0's mape: 0.0179657
# Early stopping, best iteration is:
# [20769]	valid_0's mape: 0.0179613
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0210516
# [5000]	valid_0's mape: 0.0196477
# [7500]	valid_0's mape: 0.0190719
# [10000]	valid_0's mape: 0.0187995
# [12500]	valid_0's mape: 0.0186624
# [15000]	valid_0's mape: 0.0185938
# [17500]	valid_0's mape: 0.0185592
# [20000]	valid_0's mape: 0.0185413
# Early stopping, best iteration is:
# [21756]	valid_0's mape: 0.0185284
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0207221
# [5000]	valid_0's mape: 0.0193698
# [7500]	valid_0's mape: 0.0188372
# [10000]	valid_0's mape: 0.0185908
# [12500]	valid_0's mape: 0.0184783
# [15000]	valid_0's mape: 0.0184312
# [17500]	valid_0's mape: 0.0184033
# [20000]	valid_0's mape: 0.0183883
# Early stopping, best iteration is:
# [20775]	valid_0's mape: 0.0183833
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.020273
# [5000]	valid_0's mape: 0.019139
# [7500]	valid_0's mape: 0.0187688
# [10000]	valid_0's mape: 0.0185941
# [12500]	valid_0's mape: 0.0185192
# [15000]	valid_0's mape: 0.0184973
# Early stopping, best iteration is:
# [14728]	valid_0's mape: 0.0184944
# CPU times: user 2h 16min 51s, sys: 33.9 s, total: 2h 17min 25s
# Wall time: 1h 10min 30s

# %%
lgbm_mape6
# Out:
# {'final_mape': [32.776083490318676],
#  'test_mape': [33.70492031621013,
#   33.681644910111594,
#   33.814545798132414,
#   33.26083750989338,
#   33.93643016750769],
#  'val_mape': [33.70619068919631,
#   32.46509661361721,
#   34.54264678039285,
#   32.86193074852601,
#   34.53599985578924]}

# %% [markdown]
# ### lgbm_params2
# * 위에꺼랑 파라미터 똑같은데 Standard scaling 해서 사용 노노

# %%
# %%time

lgbm_study1 = optuna.create_study()
lgbm_study1.optimize(lambda x: objective_lgbm(x, X, y2), timeout=1000, n_jobs=-1)
print(lgbm_study1.best_params, lgbm_study1.best_value)
# Out:
# Training until validation scores don't improve for 500 rounds
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's mape: 0.0216781
# [2500]	valid_0's mape: 0.0284613
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0235434
# [7500]	valid_0's mape: 0.0206289
# [10000]	valid_0's mape: 0.020005
# [5000]	valid_0's mape: 0.0251375
# [5000]	valid_0's mape: 0.0214603
# [12500]	valid_0's mape: 0.0195769
# [7500]	valid_0's mape: 0.0237265
# [15000]	valid_0's mape: 0.0192772
# [7500]	valid_0's mape: 0.0204989
# [2500]	valid_0's mape: 0.0229585
# [17500]	valid_0's mape: 0.0190547
# [10000]	valid_0's mape: 0.0228453
# [10000]	valid_0's mape: 0.0199464
# [20000]	valid_0's mape: 0.0188874
# [22500]	valid_0's mape: 0.0187669
# [12500]	valid_0's mape: 0.0222306
# [12500]	valid_0's mape: 0.01961
# [25000]	valid_0's mape: 0.0186722
# Did not meet early stopping. Best iteration is:
# [25000]	valid_0's mape: 0.0186722
# [15000]	valid_0's mape: 0.0217332
# [15000]	valid_0's mape: 0.0193565
# [5000]	valid_0's mape: 0.0204954
# Training until validation scores don't improve for 500 rounds
# [17500]	valid_0's mape: 0.0213459
# [2500]	valid_0's mape: 0.0235291
# [17500]	valid_0's mape: 0.0191687
# [5000]	valid_0's mape: 0.0215078
# [20000]	valid_0's mape: 0.0210136
# [20000]	valid_0's mape: 0.0190259
# [7500]	valid_0's mape: 0.0205504
# [7500]	valid_0's mape: 0.0196149
# [22500]	valid_0's mape: 0.0207404
# [22500]	valid_0's mape: 0.0189305
# [10000]	valid_0's mape: 0.0199811
# [12500]	valid_0's mape: 0.0196056
# [25000]	valid_0's mape: 0.0188391
# [25000]	valid_0's mape: 0.0204999
# [15000]	valid_0's mape: 0.0193651
# [27500]	valid_0's mape: 0.0187717
# [27500]	valid_0's mape: 0.0202954
# [17500]	valid_0's mape: 0.0191782
# [10000]	valid_0's mape: 0.0190772
# [30000]	valid_0's mape: 0.0187288
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0187288
# [20000]	valid_0's mape: 0.0190535
# [30000]	valid_0's mape: 0.0201266
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0201266
# [22500]	valid_0's mape: 0.0189549
# [25000]	valid_0's mape: 0.0188903
# Did not meet early stopping. Best iteration is:
# [24998]	valid_0's mape: 0.0188902
# Training until validation scores don't improve for 500 rounds
# [12500]	valid_0's mape: 0.0187254
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0286371
# [2500]	valid_0's mape: 0.0236043
# [5000]	valid_0's mape: 0.0252076
# [15000]	valid_0's mape: 0.0184768
# [5000]	valid_0's mape: 0.0213498
# [7500]	valid_0's mape: 0.0237071
# [7500]	valid_0's mape: 0.020344
# [10000]	valid_0's mape: 0.0227649
# [10000]	valid_0's mape: 0.0197482
# [17500]	valid_0's mape: 0.0182888
# [12500]	valid_0's mape: 0.0220989
# [12500]	valid_0's mape: 0.0193378
# [15000]	valid_0's mape: 0.0215812
# [15000]	valid_0's mape: 0.019018
# [17500]	valid_0's mape: 0.0211605
# [20000]	valid_0's mape: 0.0181609
# [17500]	valid_0's mape: 0.018797
# [20000]	valid_0's mape: 0.0208233
# [20000]	valid_0's mape: 0.0186085
# [22500]	valid_0's mape: 0.0205511
# [22500]	valid_0's mape: 0.0180593
# [22500]	valid_0's mape: 0.0184718
# [25000]	valid_0's mape: 0.0203121
# [25000]	valid_0's mape: 0.0183661
# [27500]	valid_0's mape: 0.0200965
# [25000]	valid_0's mape: 0.0179854
# Did not meet early stopping. Best iteration is:
# [25000]	valid_0's mape: 0.0179854
# [27500]	valid_0's mape: 0.0182819
# [30000]	valid_0's mape: 0.0199022
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0199022
# [30000]	valid_0's mape: 0.0182125
# Did not meet early stopping. Best iteration is:
# [29992]	valid_0's mape: 0.0182123
# Training until validation scores don't improve for 500 rounds
# Training until validation scores don't improve for 500 rounds
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0292379
# [2500]	valid_0's mape: 0.024486
# [5000]	valid_0's mape: 0.0260284
# [2500]	valid_0's mape: 0.0237264
# [7500]	valid_0's mape: 0.0245944
# [5000]	valid_0's mape: 0.0222937
# [10000]	valid_0's mape: 0.0236941
# [7500]	valid_0's mape: 0.021243
# [12500]	valid_0's mape: 0.0230417
# [10000]	valid_0's mape: 0.0205827
# [5000]	valid_0's mape: 0.0213118
# [15000]	valid_0's mape: 0.022537
# [12500]	valid_0's mape: 0.0201131
# [17500]	valid_0's mape: 0.0221154
# [15000]	valid_0's mape: 0.0197767
# [20000]	valid_0's mape: 0.0217559
# [7500]	valid_0's mape: 0.0203342
# [17500]	valid_0's mape: 0.0195276
# [22500]	valid_0's mape: 0.0214436
# [20000]	valid_0's mape: 0.0193287
# [25000]	valid_0's mape: 0.0211745
# [22500]	valid_0's mape: 0.0191739
# [27500]	valid_0's mape: 0.0209364
# [10000]	valid_0's mape: 0.0197495
# [25000]	valid_0's mape: 0.0190586
# [30000]	valid_0's mape: 0.0207263
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0207263
# [27500]	valid_0's mape: 0.0189572
# [30000]	valid_0's mape: 0.018881
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.018881
# Training until validation scores don't improve for 500 rounds
# [12500]	valid_0's mape: 0.0193493
# [2500]	valid_0's mape: 0.0287457
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's mape: 0.0254083
# [15000]	valid_0's mape: 0.0190819
# [2500]	valid_0's mape: 0.0240097
# [7500]	valid_0's mape: 0.0239985
# [5000]	valid_0's mape: 0.0219491
# [10000]	valid_0's mape: 0.0231701
# [17500]	valid_0's mape: 0.0188891
# [7500]	valid_0's mape: 0.0209715
# [12500]	valid_0's mape: 0.0225517
# [10000]	valid_0's mape: 0.0203265
# [15000]	valid_0's mape: 0.0220609
# [12500]	valid_0's mape: 0.0198875
# [17500]	valid_0's mape: 0.021656
# [20000]	valid_0's mape: 0.0187559
# [15000]	valid_0's mape: 0.0195824
# [20000]	valid_0's mape: 0.0213127
# [17500]	valid_0's mape: 0.0193517
# [22500]	valid_0's mape: 0.0210107
# [22500]	valid_0's mape: 0.0186491
# [20000]	valid_0's mape: 0.0191941
# [25000]	valid_0's mape: 0.0207553
# [22500]	valid_0's mape: 0.019051
# [27500]	valid_0's mape: 0.0205313
# [25000]	valid_0's mape: 0.0185724
# Did not meet early stopping. Best iteration is:
# [25000]	valid_0's mape: 0.0185724
# [25000]	valid_0's mape: 0.0189499
# [30000]	valid_0's mape: 0.0203387
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0203387
# [27500]	valid_0's mape: 0.0188644
# [30000]	valid_0's mape: 0.0188045
# Did not meet early stopping. Best iteration is:
# [29997]	valid_0's mape: 0.0188044
# Training until validation scores don't improve for 500 rounds
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.028395
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's mape: 0.0251908
# [2500]	valid_0's mape: 0.0233516
# [2500]	valid_0's mape: 0.023541
# [7500]	valid_0's mape: 0.0237748
# [5000]	valid_0's mape: 0.0214713
# [10000]	valid_0's mape: 0.0229435
# [7500]	valid_0's mape: 0.0205217
# [12500]	valid_0's mape: 0.0223339
# [5000]	valid_0's mape: 0.0210651
# [10000]	valid_0's mape: 0.0199793
# [15000]	valid_0's mape: 0.0218472
# [12500]	valid_0's mape: 0.0196199
# [17500]	valid_0's mape: 0.02146
# [15000]	valid_0's mape: 0.0193793
# [7500]	valid_0's mape: 0.0201445
# [20000]	valid_0's mape: 0.0211292
# [17500]	valid_0's mape: 0.0192116
# [22500]	valid_0's mape: 0.0208602
# [20000]	valid_0's mape: 0.0190798
# [25000]	valid_0's mape: 0.0206267
# [10000]	valid_0's mape: 0.0195623
# [22500]	valid_0's mape: 0.0189836
# [27500]	valid_0's mape: 0.0204348
# [25000]	valid_0's mape: 0.0189245
# [30000]	valid_0's mape: 0.0202644
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0202644
# [27500]	valid_0's mape: 0.0188616
# [12500]	valid_0's mape: 0.019172
# [30000]	valid_0's mape: 0.0188072
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0188072
# [15000]	valid_0's mape: 0.0189102
# {'num_leaves': 15.720775547238699, 'max_depth': 22, 'min_child_samples': 45, 'min_child_weight': 2.264542217981155, 'learning_rate': 0.0044486228697341815, 'reg_alpha': 0.8820218786083174, 'reg_lambda': 0.026471295694915672, 'min_split_gain': 0.03108699091566872, 'colsample_bytree': 0.9421645130749837, 'boost_from_average': False, 'subsample': 0.8410870101253838, 'subsample_freq': 4, 'max_bin': 35} 33.69785513181722
# CPU times: user 1h 25min 59s, sys: 9min 24s, total: 1h 35min 24s
# Wall time: 48min 48s

# %%
lgbm_params2 = lgbm_study1.best_params.copy()
lgbm_params2['num_leaves'] = int(lgbm_params2['num_leaves'])
lgbm_params2['n_jobs'] = -1
lgbm_params2['device_type'] = 'gpu', 
lgbm_params2['num_iterations'] = 30000
lgbm_params2['objective'] = 'regression'
lgbm_params2['metric'] = 'mape'
lgbm_params2['is_training_metric'] = True
lgbm_params2['verbose'] = -1

# %%
lgbm_params2
# Out:
# {'boost_from_average': False,
#  'colsample_bytree': 0.9421645130749837,
#  'device_type': ('gpu',),
#  'is_training_metric': True,
#  'learning_rate': 0.0044486228697341815,
#  'max_bin': 35,
#  'max_depth': 22,
#  'metric': 'mape',
#  'min_child_samples': 45,
#  'min_child_weight': 2.264542217981155,
#  'min_split_gain': 0.03108699091566872,
#  'n_jobs': -1,
#  'num_iterations': 30000,
#  'num_leaves': 15,
#  'objective': 'regression',
#  'reg_alpha': 0.8820218786083174,
#  'reg_lambda': 0.026471295694915672,
#  'subsample': 0.8410870101253838,
#  'subsample_freq': 4,
#  'verbose': -1}

# %%
# %%time

lgbm_mape2, lgbm_pred2, lgbm_shap2 = SHAP.lgbm_SHAP(X, y2, lgbm_params2, version='0921-lgbm-optuna', cv_splits=5, scaling="Standard", epoch=30000)
# Out:
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0235572
# [5000]	valid_0's mape: 0.0214479
# [7500]	valid_0's mape: 0.02051
# [10000]	valid_0's mape: 0.0199514
# [12500]	valid_0's mape: 0.0195776
# [15000]	valid_0's mape: 0.0193103
# [17500]	valid_0's mape: 0.0191312
# [20000]	valid_0's mape: 0.0189848
# [22500]	valid_0's mape: 0.0188847
# [25000]	valid_0's mape: 0.0188017
# [27500]	valid_0's mape: 0.0187364
# [30000]	valid_0's mape: 0.0186915
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0186915
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0235625
# [5000]	valid_0's mape: 0.0213408
# [7500]	valid_0's mape: 0.0203425
# [10000]	valid_0's mape: 0.0197302
# [12500]	valid_0's mape: 0.0193319
# [15000]	valid_0's mape: 0.0190137
# [17500]	valid_0's mape: 0.0187706
# [20000]	valid_0's mape: 0.0185957
# [22500]	valid_0's mape: 0.0184683
# [25000]	valid_0's mape: 0.0183503
# [27500]	valid_0's mape: 0.0182683
# [30000]	valid_0's mape: 0.0181971
# Did not meet early stopping. Best iteration is:
# [30000]	valid_0's mape: 0.0181971
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0244459
# [5000]	valid_0's mape: 0.0222766
# [7500]	valid_0's mape: 0.0212235
# [10000]	valid_0's mape: 0.0205685
# [12500]	valid_0's mape: 0.0200974
# [15000]	valid_0's mape: 0.0197588
# [17500]	valid_0's mape: 0.0195198
# [20000]	valid_0's mape: 0.0193184
# [22500]	valid_0's mape: 0.0191698
# [25000]	valid_0's mape: 0.0190461
# [27500]	valid_0's mape: 0.018944
# [30000]	valid_0's mape: 0.0188665
# Did not meet early stopping. Best iteration is:
# [29988]	valid_0's mape: 0.0188664
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0239404
# [5000]	valid_0's mape: 0.0218562
# [7500]	valid_0's mape: 0.0208626
# [10000]	valid_0's mape: 0.0202477
# [12500]	valid_0's mape: 0.0198234
# [15000]	valid_0's mape: 0.0195075
# [17500]	valid_0's mape: 0.0192745
# [20000]	valid_0's mape: 0.0190865
# [22500]	valid_0's mape: 0.0189616
# [25000]	valid_0's mape: 0.0188633
# [27500]	valid_0's mape: 0.0187814
# [30000]	valid_0's mape: 0.0187238
# Did not meet early stopping. Best iteration is:
# [29971]	valid_0's mape: 0.0187237
# Training until validation scores don't improve for 500 rounds
# [2500]	valid_0's mape: 0.0235616
# [5000]	valid_0's mape: 0.021496
# [7500]	valid_0's mape: 0.0205593
# [10000]	valid_0's mape: 0.0200209
# [12500]	valid_0's mape: 0.0196566
# [15000]	valid_0's mape: 0.0193846
# [17500]	valid_0's mape: 0.019209
# [20000]	valid_0's mape: 0.0190805
# [22500]	valid_0's mape: 0.0189858
# [25000]	valid_0's mape: 0.0189047
# [27500]	valid_0's mape: 0.0188406
# [30000]	valid_0's mape: 0.018795
# Did not meet early stopping. Best iteration is:
# [29989]	valid_0's mape: 0.0187949
# CPU times: user 1h 56min 31s, sys: 29.3 s, total: 1h 57min 1s
# Wall time: 1h 14s

# %%
lgbm_mape2
# Out:
# {'final_mape': [33.66846099230518],
#  'test_mape': [34.27476909639607,
#   34.34494129084431,
#   34.480448985031124,
#   34.066059999321816,
#   34.3199544625717],
#  'val_mape': [34.53151182348836,
#   33.15114511547503,
#   35.42986782793108,
#   33.59155226231744,
#   35.146519138391696]}
